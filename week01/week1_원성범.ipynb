# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# 1. 데이터 준비 및 분할
fish_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0,
                31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0,
                35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0, 9.8,
                10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]
fish_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0,
                500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0,
                700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0, 6.7,
                7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]

fish_data = np.column_stack((fish_length, fish_weight))
fish_target = np.concatenate((np.ones(35), np.zeros(14)))
train_input, test_input, train_target, test_target = train_test_split(fish_data, fish_target, stratify=fish_target, random_state=42)

# %%
# 1. 스케일링 전 데이터 시각화 ( x 축으로의 차이가 육안으로 확인하기 어려울 정도임. 그래서 길이 특성은 거의 무시하는 수준임 )
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.scatter(train_input[:, 0], train_input[:, 1], c=train_target, alpha=0.7)
plt.title('Original Data')
plt.xlabel('Length')
plt.ylabel('Weight')
plt.axis('equal') # X, Y축의 스케일을 동일하게 설정하여 왜곡 없이 시각화
# Out:
# (np.float64(8.24),
#  np.float64(42.56),
#  np.float64(-42.964999999999996),
#  np.float64(1049.665))

# %%
# 2. 스케일링 후 데이터 시각화 ( 길이와 무게를 균등하게 고려함 )
ss = StandardScaler()
ss.fit(train_input)
train_scaled = ss.transform(train_input)
plt.subplot(1, 2, 2)
plt.scatter(train_scaled[:, 0], train_scaled[:, 1], c=train_target, alpha=0.7)
plt.title('Scaled Data')
plt.xlabel('Scaled Length')
plt.ylabel('Scaled Weight')
plt.axis('equal')
plt.tight_layout()
plt.show()
